# %%
#Tocar

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Load your dataset
file_path = r'C:\Users\Subhadeep Maishal\Music\JUP\test_data\CBN_INPUT.csv'
df = pd.read_csv(file_path, parse_dates=['DATE'])

# Select features and target
features = df[['AAO', 'AO', 'DMI', 'MEIv2', 'NAO', 'ONI', 'PDO', 'SOI', 'TNA', 'TSA', 'WHWP', 'WP']]
target = df['MEIv2']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Reshape the input data for CNN
X_train_reshaped = X_train_scaled.reshape((X_train_scaled.shape[0], 12, 1))
X_test_reshaped = X_test_scaled.reshape((X_test_scaled.shape[0], 12, 1))

# Define a simpler CNN model
model = models.Sequential()

model.add(layers.Conv1D(64, kernel_size=3, activation='relu', input_shape=(12, 1)))
model.add(layers.MaxPooling1D(pool_size=2))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1, activation='linear'))  # Output layer for regression

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# Train the model and record history for plotting
history = model.fit(X_train_reshaped, y_train, epochs=20, validation_data=(X_test_reshaped, y_test))

# Predictions on the test set
predictions = model.predict(X_test_reshaped)

# Plot actual and predicted values against DATE
plt.figure(figsize=(10, 6))
plt.plot(df['DATE'].iloc[-len(y_test):], y_test, label='Actual', marker='o')
plt.plot(df['DATE'].iloc[-len(predictions):], predictions, label='Predicted', marker='o')
plt.xlabel('Date')
plt.ylabel('MEIv2 Values')
plt.title('Actual vs Predicted MEIv2 Values Over Time')
plt.legend()
plt.show()
# Out:
# WARNING:tensorflow:From C:\Users\Subhadeep Maishal\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Subhadeep Maishal\anaconda3\Lib\site-packages\keras\src\backend.py:6642: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\Subhadeep Maishal\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/20
# WARNING:tensorflow:From C:\Users\Subhadeep Maishal\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# ...

# %%
#                                              PERFECT (::)

# %%
#                             CHANGE IN (Derivative). change at a certain point :)

# %%
# OH REALLY YOU KNOW THAT     ::       read from https://www.tensorflow.org/guide/keras

# %%
#                                       "IT'S A MAGIC IN OCEAN"

# %%
#                             https://www.youtube.com/watch?v=aI3yNckfSvU

# %%
# "Oh my Royal+highness, its just a Sultry flux"       ::      not for when your domain not Nesting Ocean Models :) :)  ::

# %%
#            EPOCHS=50                     https://deepai.org/machine-learning-glossary-and-terms/epoch

# %%
#                     IT'S POWER OF EPOCHS   ....DO NOT INCREASE TOO MUCH.       ;-)

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Load your dataset
file_path = r'C:\Users\Subhadeep Maishal\Music\JUP\test_data\CBN_INPUT.csv'
df = pd.read_csv(file_path, parse_dates=['DATE'])

# Select features and target
features = df[['AAO', 'AO', 'DMI', 'MEIv2', 'NAO', 'ONI', 'PDO', 'SOI', 'TNA', 'TSA', 'WHWP', 'WP']]
target = df['MEIv2']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Reshape the input data for CNN
X_train_reshaped = X_train_scaled.reshape((X_train_scaled.shape[0], 12, 1))
X_test_reshaped = X_test_scaled.reshape((X_test_scaled.shape[0], 12, 1))

# Define a simpler CNN model
model = models.Sequential()

model.add(layers.Conv1D(64, kernel_size=3, activation='relu', input_shape=(12, 1)))
model.add(layers.MaxPooling1D(pool_size=2))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1, activation='linear'))  # Output layer for regression

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# Train the model and record history for plotting
#                            YOU THINK ITS NOTHIG ......SHEET
history = model.fit(X_train_reshaped, y_train, epochs=50, validation_data=(X_test_reshaped, y_test))

# Predictions on the test set
predictions = model.predict(X_test_reshaped)

# Plot actual and predicted values against DATE
plt.figure(figsize=(10, 6))
plt.plot(df['DATE'].iloc[-len(y_test):], y_test, label='Actual', marker='o')
plt.plot(df['DATE'].iloc[-len(predictions):], predictions, label='Predicted', marker='o')
plt.xlabel('Date')
plt.ylabel('MEIv2 Values')
plt.title('Actual vs Predicted MEIv2 Values Over Time')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 11/11 [==============================] - 1s 18ms/step - loss: 0.5687 - mae: 0.6025 - val_loss: 0.2467 - val_mae: 0.3885
# Epoch 2/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1554 - mae: 0.3134 - val_loss: 0.1502 - val_mae: 0.3047
# Epoch 3/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1210 - mae: 0.2727 - val_loss: 0.1045 - val_mae: 0.2612
# Epoch 4/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0902 - mae: 0.2475 - val_loss: 0.0993 - val_mae: 0.2560
# Epoch 5/50
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0834 - mae: 0.2364 - val_loss: 0.0837 - val_mae: 0.2317
# Epoch 6/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0718 - mae: 0.2140 - val_loss: 0.0835 - val_mae: 0.2290
# Epoch 7/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0649 - mae: 0.2079 - val_loss: 0.0716 - val_mae: 0.2163
# Epoch 8/50
# ...

# %%
#                                         :::      SENSUALITY     :::

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Load your dataset
file_path = r'C:\Users\Subhadeep Maishal\Music\JUP\test_data\CBN_INPUT.csv'
df = pd.read_csv(file_path, parse_dates=['DATE'])

# Remove 'MEIv2' from features
features = df[['AAO', 'AO', 'DMI', 'NAO', 'ONI', 'PDO', 'SOI', 'TNA', 'TSA', 'WHWP', 'WP']]
target = df['MEIv2']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Reshape the input data for CNN
X_train_reshaped = X_train_scaled.reshape((X_train_scaled.shape[0], 11, 1))  # Adjust the shape based on the number of features
X_test_reshaped = X_test_scaled.reshape((X_test_scaled.shape[0], 11, 1))

# Define a simpler CNN model
model = models.Sequential()

model.add(layers.Conv1D(64, kernel_size=3, activation='relu', input_shape=(11, 1)))  # Adjust input shape
model.add(layers.MaxPooling1D(pool_size=2))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1, activation='linear'))  # Output layer for regression

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# Train the model and record history for plotting
history = model.fit(X_train_reshaped, y_train, epochs=50, validation_data=(X_test_reshaped, y_test))

# Predictions on the test set
predictions = model.predict(X_test_reshaped)

# Plot actual and predicted values against DATE
plt.figure(figsize=(10, 6))
plt.plot(df['DATE'].iloc[-len(y_test):], y_test, label='Actual', marker='o')
plt.plot(df['DATE'].iloc[-len(predictions):], predictions, label='Predicted', marker='o')
plt.xlabel('Date')
plt.ylabel('MEIv2 Values')
plt.title('Actual vs Predicted MEIv2 Values Over Time')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 11/11 [==============================] - 1s 21ms/step - loss: 0.6372 - mae: 0.6406 - val_loss: 0.4548 - val_mae: 0.5526
# Epoch 2/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2888 - mae: 0.4314 - val_loss: 0.2708 - val_mae: 0.4167
# Epoch 3/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2209 - mae: 0.3813 - val_loss: 0.2338 - val_mae: 0.3892
# Epoch 4/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1846 - mae: 0.3486 - val_loss: 0.2231 - val_mae: 0.3804
# Epoch 5/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1564 - mae: 0.3133 - val_loss: 0.2032 - val_mae: 0.3633
# Epoch 6/50
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1354 - mae: 0.2904 - val_loss: 0.1867 - val_mae: 0.3490
# Epoch 7/50
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1222 - mae: 0.2764 - val_loss: 0.1796 - val_mae: 0.3438
# Epoch 8/50
# ...

# %%
#                                 REMOVE--ED MEIv2 FROM TRAINING :))

# %%
# NOW,    model.add(layers.Conv1D(64, kernel_size=3, activation='relu', input_shape=(11, 1)))

# %%
# input_shape=(11, 1)     NOW IT'S  11   (ITS NOT CRICKET)     IT'S JUST  Conv1D      Convolutional<------->1D

# %%
# DON'T "TOUCH" 2D    ::      OTHERWISE ITS MAKE U MADE ::  I LOVE MY MADNESS  WITH "SOME<SUM>" GOOD DRINKS! ::

# %%
#                ::                NOW AGAIN INCRISING EPOCHS=100                ::

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Load your dataset
file_path = r'C:\Users\Subhadeep Maishal\Music\JUP\test_data\CBN_INPUT.csv'
df = pd.read_csv(file_path, parse_dates=['DATE'])

# Remove 'MEIv2' from features
features = df[['AAO', 'AO', 'DMI', 'NAO', 'ONI', 'PDO', 'SOI', 'TNA', 'TSA', 'WHWP', 'WP']]
target = df['MEIv2']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Reshape the input data for CNN
X_train_reshaped = X_train_scaled.reshape((X_train_scaled.shape[0], 11, 1))  # Adjust the shape based on the number of features
X_test_reshaped = X_test_scaled.reshape((X_test_scaled.shape[0], 11, 1))

# Define a simpler CNN model
model = models.Sequential()

model.add(layers.Conv1D(64, kernel_size=3, activation='relu', input_shape=(11, 1)))  # Adjust input shape
model.add(layers.MaxPooling1D(pool_size=2))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1, activation='linear'))  # Output layer for regression

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# Train the model and record history for plotting
history = model.fit(X_train_reshaped, y_train, epochs=100, validation_data=(X_test_reshaped, y_test))

# Predictions on the test set
predictions = model.predict(X_test_reshaped)

# Plot actual and predicted values against DATE
plt.figure(figsize=(10, 6))
plt.plot(df['DATE'].iloc[-len(y_test):], y_test, label='Actual', marker='o')
plt.plot(df['DATE'].iloc[-len(predictions):], predictions, label='Predicted', marker='o')
plt.xlabel('Date')
plt.ylabel('MEIv2 Values')
plt.title('Actual vs Predicted MEIv2 Values Over Time')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 11/11 [==============================] - 1s 19ms/step - loss: 0.5637 - mae: 0.5909 - val_loss: 0.3574 - val_mae: 0.4708
# Epoch 2/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2305 - mae: 0.3761 - val_loss: 0.2779 - val_mae: 0.4262
# Epoch 3/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1942 - mae: 0.3558 - val_loss: 0.2318 - val_mae: 0.3880
# Epoch 4/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1534 - mae: 0.3083 - val_loss: 0.2160 - val_mae: 0.3750
# Epoch 5/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1312 - mae: 0.2831 - val_loss: 0.1953 - val_mae: 0.3573
# Epoch 6/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1141 - mae: 0.2664 - val_loss: 0.1817 - val_mae: 0.3457
# Epoch 7/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1039 - mae: 0.2528 - val_loss: 0.1686 - val_mae: 0.3312
# Epoch 8/100
# ...

# %%
#                            https://www.youtube.com/watch?v=gMqtDaWHG9I

# %%
#                ::                NOW AGAIN INCRISING EPOCHS=100                ::                  R U MADE

# %%
#  USE earphone with HIGH       ::       CLOSE THE EYES         ::               LISTING GOOD MUSIC ALWAYS GOOD 4U

# %%
#                   (-; (-; (-;      NOW CLOSE THE DOOR, REALY    :) :) :)

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Load your dataset
file_path = r'C:\Users\Subhadeep Maishal\Music\JUP\test_data\CBN_INPUT.csv'
df = pd.read_csv(file_path, parse_dates=['DATE'])

# Remove 'MEIv2' from features
features = df[['AAO', 'AO', 'DMI', 'NAO', 'ONI', 'PDO', 'SOI', 'TNA', 'TSA', 'WHWP', 'WP']]
target = df['MEIv2']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Reshape the input data for CNN
X_train_reshaped = X_train_scaled.reshape((X_train_scaled.shape[0], 11, 1))  # Adjust the shape based on the number of features
X_test_reshaped = X_test_scaled.reshape((X_test_scaled.shape[0], 11, 1))

# Define a simpler CNN model
model = models.Sequential()

model.add(layers.Conv1D(64, kernel_size=3, activation='relu', input_shape=(11, 1)))  # Adjust input shape
model.add(layers.MaxPooling1D(pool_size=2))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1, activation='linear'))  # Output layer for regression

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# Train the model and record history for plotting
history = model.fit(X_train_reshaped, y_train, epochs=1000, validation_data=(X_test_reshaped, y_test))

# Predictions on the test set
predictions = model.predict(X_test_reshaped)

# Plot actual and predicted values against DATE
plt.figure(figsize=(10, 6))
plt.plot(df['DATE'].iloc[-len(y_test):], y_test, label='Actual', marker='o')
plt.plot(df['DATE'].iloc[-len(predictions):], predictions, label='Predicted', marker='o')
plt.xlabel('Date')
plt.ylabel('MEIv2 Values')
plt.title('Actual vs Predicted MEIv2 Values Over Time')
plt.legend()
plt.show()
# Out:
# Epoch 1/1000
# 11/11 [==============================] - 1s 19ms/step - loss: 0.5225 - mae: 0.5644 - val_loss: 0.2722 - val_mae: 0.4203
# Epoch 2/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2192 - mae: 0.3742 - val_loss: 0.2408 - val_mae: 0.4003
# Epoch 3/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1780 - mae: 0.3376 - val_loss: 0.2061 - val_mae: 0.3657
# Epoch 4/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1460 - mae: 0.3020 - val_loss: 0.1951 - val_mae: 0.3578
# Epoch 5/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1249 - mae: 0.2798 - val_loss: 0.1837 - val_mae: 0.3481
# Epoch 6/1000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1108 - mae: 0.2616 - val_loss: 0.1790 - val_mae: 0.3465
# Epoch 7/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.1105 - mae: 0.2598 - val_loss: 0.1668 - val_mae: 0.3293
# Epoch 8/1000
# ...

# %%
#                 ::                  NOW TEST WITH INCRISING EPOCHS=1000                ::

# %%
#                                        "YOU ALREADY TESTS OF TEST"

# %%
#                                            IT'S A "HEAT"  OR  HOT

# %%
#                                                "I LIKE BOTHs"

# %%
#                                   https://www.youtube.com/watch?v=YeeHZR5Jjjw

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Load your dataset
file_path = r'C:\Users\Subhadeep Maishal\Music\JUP\test_data\CBN_INPUT.csv'
df = pd.read_csv(file_path, parse_dates=['DATE'])

# Remove 'MEIv2' from features
features = df[['AAO', 'AO', 'DMI', 'NAO', 'ONI', 'PDO', 'SOI', 'TNA', 'TSA', 'WHWP', 'WP']]
target = df['MEIv2']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Reshape the input data for CNN
X_train_reshaped = X_train_scaled.reshape((X_train_scaled.shape[0], 11, 1))  # Adjust the shape based on the number of features
X_test_reshaped = X_test_scaled.reshape((X_test_scaled.shape[0], 11, 1))

# Define a simpler CNN model
model = models.Sequential()

model.add(layers.Conv1D(64, kernel_size=3, activation='relu', input_shape=(11, 1)))  # Adjust input shape
model.add(layers.MaxPooling1D(pool_size=2))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1, activation='linear'))  # Output layer for regression

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# Train the model and record history for plotting
history = model.fit(X_train_reshaped, y_train, epochs=2000, validation_data=(X_test_reshaped, y_test))

# Predictions on the test set
predictions = model.predict(X_test_reshaped)

# Plot actual and predicted values against DATE
plt.figure(figsize=(10, 6))
plt.plot(df['DATE'].iloc[-len(y_test):], y_test, label='Actual', marker='o')
plt.plot(df['DATE'].iloc[-len(predictions):], predictions, label='Predicted', marker='o')
plt.xlabel('Date')
plt.ylabel('MEIv2 Values')
plt.title('Actual vs Predicted MEIv2 Values Over Time')
plt.legend()
plt.show()
# Out:
# Epoch 1/2000
# 11/11 [==============================] - 1s 20ms/step - loss: 0.5874 - mae: 0.6084 - val_loss: 0.3739 - val_mae: 0.5017
# Epoch 2/2000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2204 - mae: 0.3746 - val_loss: 0.2429 - val_mae: 0.3921
# Epoch 3/2000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1832 - mae: 0.3427 - val_loss: 0.2114 - val_mae: 0.3704
# Epoch 4/2000
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1552 - mae: 0.3141 - val_loss: 0.2032 - val_mae: 0.3616
# Epoch 5/2000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1333 - mae: 0.2897 - val_loss: 0.1854 - val_mae: 0.3429
# Epoch 6/2000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1241 - mae: 0.2800 - val_loss: 0.1844 - val_mae: 0.3455
# Epoch 7/2000
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1134 - mae: 0.2664 - val_loss: 0.1832 - val_mae: 0.3336
# Epoch 8/2000
# ...

# %%
#                                           MAKE IT LIKE "adam" LIKEs

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

# Load your dataset
file_path = r'C:\Users\Subhadeep Maishal\Music\JUP\test_data\CBN_INPUT.csv'
df = pd.read_csv(file_path, parse_dates=['DATE'])

# Remove 'MEIv2' from features
features = df[['AAO', 'AO', 'DMI', 'NAO', 'ONI', 'PDO', 'SOI', 'TNA', 'TSA', 'WHWP', 'WP']]
target = df['MEIv2']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Reshape the input data for CNN
X_train_reshaped = X_train_scaled.reshape((X_train_scaled.shape[0], 11, 1))  # Adjust the shape based on the number of features
X_test_reshaped = X_test_scaled.reshape((X_test_scaled.shape[0], 11, 1))

# Define a simpler CNN model
model = models.Sequential()

model.add(layers.Conv1D(64, kernel_size=3, activation='relu', input_shape=(11, 1)))  # Adjust input shape
model.add(layers.MaxPooling1D(pool_size=2))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1, activation='linear'))  # Output layer for regression

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# Train the model and record history for plotting
history = model.fit(X_train_reshaped, y_train, epochs=10000, validation_data=(X_test_reshaped, y_test))

# Predictions on the test set
predictions = model.predict(X_test_reshaped)

# Set seaborn style
sns.set(style="whitegrid")

# Plot actual and predicted values against DATE
plt.figure(figsize=(12, 8))
plt.plot(df['DATE'].iloc[-len(y_test):], y_test, label='Actual', marker='o', color='black')
plt.plot(df['DATE'].iloc[-len(predictions):], predictions, label='Predicted', marker='o', color='blue')
plt.xlabel('Date', fontsize=14)
plt.ylabel('MEIv2 Values', fontsize=14)
plt.title('Actual vs Predicted MEIv2 Values Over Time', fontsize=16)
plt.legend(fontsize=12)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.tight_layout()
plt.show()
# Out:
# Epoch 1/10000
# 11/11 [==============================] - 1s 19ms/step - loss: 0.5226 - mae: 0.5662 - val_loss: 0.3144 - val_mae: 0.4491
# Epoch 2/10000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2156 - mae: 0.3725 - val_loss: 0.2872 - val_mae: 0.4340
# Epoch 3/10000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1839 - mae: 0.3431 - val_loss: 0.2482 - val_mae: 0.4003
# Epoch 4/10000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1583 - mae: 0.3168 - val_loss: 0.2275 - val_mae: 0.3838
# Epoch 5/10000
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1350 - mae: 0.2899 - val_loss: 0.1925 - val_mae: 0.3517
# Epoch 6/10000
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1210 - mae: 0.2747 - val_loss: 0.1829 - val_mae: 0.3428
# Epoch 7/10000
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1078 - mae: 0.2551 - val_loss: 0.1790 - val_mae: 0.3405
# Epoch 8/10000
# ...

# %%
#                        ::           NOW WE PREDICTED THE HOTEST      [təˈɡeT͟Hər]    ::
